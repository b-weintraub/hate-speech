# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

from src.roc import plot_roc_curve

# %%
proba_true_bert = np.loadtxt('data/bert_y_pred_proba.txt')
y_test_bert = np.loadtxt('data/bert_y_test.txt')

proba_true_tfidf = np.loadtxt('data/TDIDF-LR_y_pred_proba.txt')
y_test_tfidf = np.loadtxt('data/TDIDF-LR_y_test.txt')

# %%
# plot ROC

fig,ax= plt.subplots(figsize=(8,8))

plot_roc_curve(proba_true_bert, y_test_bert, ax, title="BERT - Logistic Regression", color='r')
plot_roc_curve(proba_true_tfidf, y_test_tfidf, ax, title="TFIDF - Logistic Regression", color='b')

fig.savefig('img/roc_overlay-BERT-TFIDF.png')
